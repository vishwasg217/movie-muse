# %%
import pandas as pd
import json

print("hello")
# Out:
# hello

# %%
attribs = pd.read_json("../data/processed/movie_attributes.json", orient="index")
attribs.reset_index(inplace=True)
attribs.columns = ["title", "attributes"]
attribs
# Out:
#                         title  \
# 0    The Shawshank Redemption
# 1             The Dark Knight
# 2                   Inception
# 3                  Fight Club
# 4                Forrest Gump
# ..                        ...
# 989                  Rocky II
# 990                    Misery
# 991         Godzilla vs. Kong
# 992          Anger Management
# 993                 Project X
#
#                                             attributes
# 0    compassion, friendship, redemption, consolatio...
# 1    Excitement, Suspense, Thrill, Tension, Intensi...
# 2    excitement, suspense, intrigue, thrill, awe, w...
# 3    excitement, suspense, intrigue, rebellion, int...
# 4    nostalgic, heartwarming, inspiring, bitterswee...
# ..                                                 ...
# 989  determined, motivated, resilient, passionate, ...
# 990  Suspense, fear, tension, anxiety, dread, uneas...
# 991  Excitement, Suspense, Fear, Wonder, Thrill, In...
# 992  Excitement, Laughter, Surprise, Tension, Happi...
# 993  excitement, chaos, thrill, frenzy, exhilaratio...
#
# [994 rows x 2 columns]

# %%
movies = pd.read_csv('../data/processed/movie_and_plot.csv')
movies.head()
# Out:
#    movie_id                     title  year                   genres  \
# 0    111161  The Shawshank Redemption  1994                    Drama
# 1    468569           The Dark Knight  2008       Action,Crime,Drama
# 2   1375666                 Inception  2010  Action,Adventure,Sci-Fi
# 3    137523                Fight Club  1999                    Drama
# 4    109830              Forrest Gump  1994            Drama,Romance
#
#    average_rating  num_votes  \
# 0             9.3    2773389
# 1             9.0    2749040
# 2             8.8    2439868
# 3             8.8    2209229
# 4             8.8    2156978
#
#                                                 plot
# 0  Over the course of several years, two convicts...
# 1  When the menace known as the Joker wreaks havo...
# 2  A thief who steals corporate secrets through t...
# 3  An insomniac office worker and a devil-may-car...
# 4  The history of the United States from the 1950...

# %%
df = pd.merge(movies, attribs, on="title", how="inner")
df
# Out:
#      movie_id                     title  year                   genres  \
# 0      111161  The Shawshank Redemption  1994                    Drama
# 1      468569           The Dark Knight  2008       Action,Crime,Drama
# 2     1375666                 Inception  2010  Action,Adventure,Sci-Fi
# 3      137523                Fight Club  1999                    Drama
# 4      109830              Forrest Gump  1994            Drama,Romance
# ..        ...                       ...   ...                      ...
# 995     79817                  Rocky II  1979              Drama,Sport
# 996    100157                    Misery  1990           Drama,Thriller
# 997   5034838         Godzilla vs. Kong  2021   Action,Sci-Fi,Thriller
# 998    305224          Anger Management  2003                   Comedy
# 999   1636826                 Project X  2012                   Comedy
#
#      average_rating  num_votes  \
# 0               9.3    2773389
# 1               9.0    2749040
# 2               8.8    2439868
# 3               8.8    2209229
# 4               8.8    2156978
# ..              ...        ...
# 995             7.3     223151
# 996             7.8     223054
# 997             6.3     222703
# 998             6.2     222485
# 999             6.6     222302
#
#                                                   plot  \
# 0    Over the course of several years, two convicts...
# 1    When the menace known as the Joker wreaks havo...
# 2    A thief who steals corporate secrets through t...
# 3    An insomniac office worker and a devil-may-car...
# 4    The history of the United States from the 1950...
# ..                                                 ...
# 995  Rocky struggles in family life after his bout ...
# 996  After a famous author is rescued from a car cr...
# 997  The epic next chapter in the cinematic Monster...
# 998  Dave Buznik is a businessman who is wrongly se...
# 999  Three high-school seniors throw a birthday par...
#
#                                             attributes
# 0    compassion, friendship, redemption, consolatio...
# 1    Excitement, Suspense, Thrill, Tension, Intensi...
# 2    excitement, suspense, intrigue, thrill, awe, w...
# 3    excitement, suspense, intrigue, rebellion, int...
# 4    nostalgic, heartwarming, inspiring, bitterswee...
# ..                                                 ...
# 995  determined, motivated, resilient, passionate, ...
# 996  Suspense, fear, tension, anxiety, dread, uneas...
# 997  Excitement, Suspense, Fear, Wonder, Thrill, In...
# 998  Excitement, Laughter, Surprise, Tension, Happi...
# 999  excitement, chaos, thrill, frenzy, exhilaratio...
#
# [1000 rows x 8 columns]

# %%
df.drop(columns = ['plot'], inplace=True)
data_list = df.to_dict(orient='records')
json_data = {item['title']: {key: value for key, value in item.items() if key != 'title'} for item in data_list}
json_data
# Out:
# {'The Shawshank Redemption': {'movie_id': 111161,
#   'year': 1994,
#   'genres': 'Drama',
#   'average_rating': 9.3,
#   'num_votes': 2773389,
#   'attributes': 'compassion, friendship, redemption, consolation, drama, hope, resilience, perseverance'},
#  'The Dark Knight': {'movie_id': 468569,
#   'year': 2008,
#   'genres': 'Action,Crime,Drama',
#   'average_rating': 9.0,
#   'num_votes': 2749040,
#   'attributes': 'Excitement, Suspense, Thrill, Tension, Intensity, Intrigue, Drama, Fear'},
#  'Inception': {'movie_id': 1375666,
#   'year': 2010,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 8.8,
#   'num_votes': 2439868,
#   'attributes': 'excitement, suspense, intrigue, thrill, awe, wonder, anticipation, curiosity'},
#  'Fight Club': {'movie_id': 137523,
#   'year': 1999,
#   'genres': 'Drama',
#   'average_rating': 8.8,
#   'num_votes': 2209229,
#   'attributes': 'excitement, suspense, intrigue, rebellion, intensity, confusion, thrill, curiosity'},
#  'Forrest Gump': {'movie_id': 109830,
#   'year': 1994,
#   'genres': 'Drama,Romance',
#   'average_rating': 8.8,
#   'num_votes': 2156978,
#   'attributes': 'nostalgic, heartwarming, inspiring, bittersweet, uplifting, sentimental, touching, optimistic'},
#  'Pulp Fiction': {'movie_id': 110912,
#   'year': 1994,
#   'genres': 'Crime,Drama',
#   'average_rating': 8.9,
#   'num_votes': 2128442,
#   'attributes': 'Excitement, Suspense, Intrigue, Thrill, Tension, Surprise, Intensity, Satisfaction'},
#  'The Matrix': {'movie_id': 133093,
#   'year': 1999,
#   'genres': 'Action,Sci-Fi',
#   'average_rating': 8.7,
#   'num_votes': 1974333,
#   'attributes': 'Excitement, Suspense, Thrilling, Intrigue, Astonishment, Amazement, Curiosity, Wonder'},
#  'Interstellar': {'movie_id': 816692,
#   'year': 2014,
#   'genres': 'Adventure,Drama,Sci-Fi',
#   'average_rating': 8.7,
#   'num_votes': 1949126,
#   'attributes': 'Excitement, Intrigue, Wonder, Hope, Tension, Curiosity, Inspiration, Amazement'},
#  'The Godfather': {'movie_id': 68646,
#   'year': 1972,
#   'genres': 'Crime,Drama',
#   'average_rating': 9.2,
#   'num_votes': 1930630,
#   'attributes': 'excitement, suspense, tension, fear, intrigue, loyalty, betrayal, revenge'},
#  'The Lord of the Rings: The Fellowship of the Ring': {'movie_id': 120737,
#   'year': 2001,
#   'genres': 'Action,Adventure,Drama',
#   'average_rating': 8.8,
#   'num_votes': 1930403,
#   'attributes': 'Excitement, Suspense, Adventure, Thrilling, Epic, Inspiring, Intense, Emotional'},
#  'The Lord of the Rings: The Return of the King': {'movie_id': 167260,
#   'year': 2003,
#   'genres': 'Action,Adventure,Drama',
#   'average_rating': 9.0,
#   'num_votes': 1902116,
#   'attributes': 'Excitement, Suspense, Thrill, Inspiration, Hope, Courage, Determination, Triumph'},
#  'The Dark Knight Rises': {'movie_id': 1345836,
#   'year': 2012,
#   'genres': 'Action,Drama,Thriller',
#   'average_rating': 8.4,
#   'num_votes': 1758624,
#   'attributes': 'Excitement, Suspense, Tension, Intensity, Thrill, Intrigue, Anticipation, Surprise'},
#  'The Lord of the Rings: The Two Towers': {'movie_id': 167261,
#   'year': 2002,
#   'genres': 'Action,Adventure,Drama',
#   'average_rating': 8.8,
#   'num_votes': 1716460,
#   'attributes': 'Excitement, Suspense, Adventure, Thrilling, Intensity, Tension, Drama, Action'},
#  'Se7en': {'movie_id': 114369,
#   'year': 1995,
#   'genres': 'Crime,Drama,Mystery',
#   'average_rating': 8.6,
#   'num_votes': 1715507,
#   'attributes': 'Suspense, Thrilling, Dark, Intense, Disturbing, Mysterious, Gripping, Tense'},
#  'Django Unchained': {'movie_id': 1853728,
#   'year': 2012,
#   'genres': 'Drama,Western',
#   'average_rating': 8.4,
#   'num_votes': 1617197,
#   'attributes': 'Excitement, Suspense, Empathy, Tension, Revenge, Justice, Freedom, Love'},
#  'Gladiator': {'movie_id': 172495,
#   'year': 2000,
#   'genres': 'Action,Adventure,Drama',
#   'average_rating': 8.5,
#   'num_votes': 1548727,
#   'attributes': 'Excitement, Suspense, Thrill, Revenge, Determination, Grief, Justice, Redemption'},
#  'Batman Begins': {'movie_id': 372784,
#   'year': 2005,
#   'genres': 'Action,Crime,Drama',
#   'average_rating': 8.2,
#   'num_votes': 1518548,
#   'attributes': 'Excitement, Suspense, Thrill, Intensity, Tension, Intrigue, Adrenaline, Empowerment'},
#  'Inglourious Basterds': {'movie_id': 361748,
#   'year': 2009,
#   'genres': 'Adventure,Drama,War',
#   'average_rating': 8.3,
#   'num_votes': 1507949,
#   'attributes': 'excitement, suspense, revenge, determination, bravery, justice, satisfaction, triumph'},
#  'The Wolf of Wall Street': {'movie_id': 993846,
#   'year': 2013,
#   'genres': 'Biography,Comedy,Crime',
#   'average_rating': 8.2,
#   'num_votes': 1483735,
#   'attributes': 'Excitement, Humor, Thrill, Suspense, Intrigue, Amusement, Fascination, Surprise'},
#  'The Silence of the Lambs': {'movie_id': 102926,
#   'year': 1991,
#   'genres': 'Crime,Drama,Thriller',
#   'average_rating': 8.6,
#   'num_votes': 1480078,
#   'attributes': 'suspense, fear, tension, intrigue, excitement, anticipation, unease, thrill'},
#  'Saving Private Ryan': {'movie_id': 120815,
#   'year': 1998,
#   'genres': 'Drama,War',
#   'average_rating': 8.6,
#   'num_votes': 1436584,
#   'attributes': 'Excitement, Suspense, Tension, Sadness, Courage, Grief, Patriotism, Sacrifice'},
#  'The Avengers': {'movie_id': 848228,
#   'year': 2012,
#   'genres': 'Action,Sci-Fi',
#   'average_rating': 8.0,
#   'num_votes': 1424847,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Amazement, Inspiration, Heroism, Determination'},
#  'Star Wars: Episode IV - A New Hope': {'movie_id': 76759,
#   'year': 1977,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 8.6,
#   'num_votes': 1404057,
#   'attributes': 'Excitement, Adventure, Thrill, Hope, Suspense, Heroism, Determination, Amazement'},
#  "Schindler's List": {'movie_id': 108052,
#   'year': 1993,
#   'genres': 'Biography,Drama,History',
#   'average_rating': 9.0,
#   'num_votes': 1396262,
#   'attributes': 'emotions: empathy, sorrow, compassion, inspiration, admiration, shock, hope, gratitude'},
#  'The Prestige': {'movie_id': 482571,
#   'year': 2006,
#   'genres': 'Drama,Mystery,Sci-Fi',
#   'average_rating': 8.5,
#   'num_votes': 1379263,
#   'attributes': 'suspense, intrigue, rivalry, obsession, deception, sacrifice, mystery, tension'},
#  'Shutter Island': {'movie_id': 1130884,
#   'year': 2010,
#   'genres': 'Mystery,Thriller',
#   'average_rating': 8.2,
#   'num_votes': 1378104,
#   'attributes': 'suspense, intrigue, confusion, fear, curiosity, tension, surprise, anticipation'},
#  'Joker': {'movie_id': 7286456,
#   'year': 2019,
#   'genres': 'Crime,Drama,Thriller',
#   'average_rating': 8.4,
#   'num_votes': 1377304,
#   'attributes': 'excitement, suspense, tension, fear, anger, confusion, empathy, anticipation'},
#  'The Departed': {'movie_id': 407887,
#   'year': 2006,
#   'genres': 'Crime,Drama,Thriller',
#   'average_rating': 8.5,
#   'num_votes': 1368228,
#   'attributes': 'Excitement, Suspense, Intrigue, Tension, Suspicion, Betrayal, Intensity, Uncertainty'},
#  'Avatar': {'movie_id': 499549,
#   'year': 2009,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 7.9,
#   'num_votes': 1354701,
#   'attributes': 'Excitement, Adventure, Thrilling, Suspense, Wonder, Fascination, Empathy, Inspiration'},
#  'The Green Mile': {'movie_id': 120689,
#   'year': 1999,
#   'genres': 'Crime,Drama,Fantasy',
#   'average_rating': 8.6,
#   'num_votes': 1348180,
#   'attributes': 'emotions: suspense, empathy, hope, sadness, awe, compassion, tension, relief'},
#  'Star Wars: Episode V - The Empire Strikes Back': {'movie_id': 80684,
#   'year': 1980,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 8.7,
#   'num_votes': 1331937,
#   'attributes': 'Excitement, Suspense, Adventure, Thrill, Fascination, Wonder, Anticipation, Amazement'},
#  'The Godfather Part II': {'movie_id': 71562,
#   'year': 1974,
#   'genres': 'Crime,Drama',
#   'average_rating': 9.0,
#   'num_votes': 1312953,
#   'attributes': 'Excitement, Suspense, Intrigue, Intensity, Tension, Drama, Power, Ambition'},
#  'Memento': {'movie_id': 209144,
#   'year': 2000,
#   'genres': 'Mystery,Thriller',
#   'average_rating': 8.4,
#   'num_votes': 1274695,
#   'attributes': 'Suspense, Intrigue, Confusion, Tension, Curiosity, Paranoia, Uncertainty, Intricacy'},
#  'Back to the Future': {'movie_id': 88763,
#   'year': 1985,
#   'genres': 'Adventure,Comedy,Sci-Fi',
#   'average_rating': 8.5,
#   'num_votes': 1251859,
#   'attributes': 'Excitement, Nostalgia, Adventure, Humor, Amazement, Thrill, Wonder, Amusement'},
#  'Titanic': {'movie_id': 120338,
#   'year': 1997,
#   'genres': 'Drama,Romance',
#   'average_rating': 7.9,
#   'num_votes': 1236602,
#   'attributes': 'romantic, tragic, heartwarming, nostalgic, dramatic, emotional, bittersweet, intense'},
#  'Guardians of the Galaxy': {'movie_id': 2015381,
#   'year': 2014,
#   'genres': 'Action,Adventure,Comedy',
#   'average_rating': 8.0,
#   'num_votes': 1231948,
#   'attributes': 'Excitement, Thrill, Humor, Adventure, Action, Suspense, Entertainment, Fun'},
#  'Goodfellas': {'movie_id': 99685,
#   'year': 1990,
#   'genres': 'Biography,Crime,Drama',
#   'average_rating': 8.7,
#   'num_votes': 1203421,
#   'attributes': 'Excitement, Suspense, Intrigue, Intensity, Tension, Thrill, Drama, Fascination'},
#  'Léon: The Professional': {'movie_id': 110413,
#   'year': 1994,
#   'genres': 'Action,Crime,Drama',
#   'average_rating': 8.5,
#   'num_votes': 1199445,
#   'attributes': 'Excitement, Suspense, Tension, Intrigue, Empathy, Fear, Curiosity, Adrenaline'},
#  'Avengers: Endgame': {'movie_id': 4154796,
#   'year': 2019,
#   'genres': 'Action,Adventure,Drama',
#   'average_rating': 8.4,
#   'num_votes': 1198234,
#   'attributes': 'Excitement, Suspense, Thrill, Inspiration, Hope, Determination, Resilience, Triumph'},
#  'American Beauty': {'movie_id': 169547,
#   'year': 1999,
#   'genres': 'Drama',
#   'average_rating': 8.3,
#   'num_votes': 1179662,
#   'attributes': 'emotions: intrigue, desire, confusion, curiosity, longing, dissatisfaction, introspection, temptation'},
#  'Pirates of the Caribbean: The Curse of the Black Pearl': {'movie_id': 325980,
#   'year': 2003,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 8.1,
#   'num_votes': 1164110,
#   'attributes': 'Excitement, Suspense, Adventure, Thrill, Amazement, Wonder, Anticipation, Surprise'},
#  'WALL·E': {'movie_id': 910970,
#   'year': 2008,
#   'genres': 'Adventure,Animation,Family',
#   'average_rating': 8.4,
#   'num_votes': 1154138,
#   'attributes': 'Excitement, Wonder, Joy, Hope, Amazement, Curiosity, Inspiration, Nostalgia'},
#  'American History X': {'movie_id': 120586,
#   'year': 1998,
#   'genres': 'Crime,Drama',
#   'average_rating': 8.5,
#   'num_votes': 1150730,
#   'attributes': 'violence, change, hope, idolization, redemption, prejudice, transformation, brotherhood'},
#  'Kill Bill: Vol. 1': {'movie_id': 266697,
#   'year': 2003,
#   'genres': 'Action,Crime,Thriller',
#   'average_rating': 8.2,
#   'num_votes': 1149370,
#   'attributes': 'Excitement, Suspense, Revenge, Intensity, Thrill, Action, Intrigue, Tension'},
#  'V for Vendetta': {'movie_id': 434409,
#   'year': 2005,
#   'genres': 'Action,Drama,Sci-Fi',
#   'average_rating': 8.2,
#   'num_votes': 1147262,
#   'attributes': 'Excitement, Suspense, Rebellion, Hope, Empowerment, Justice, Inspiration, Love'},
#  'Avengers: Infinity War': {'movie_id': 4154756,
#   'year': 2018,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 8.4,
#   'num_votes': 1140326,
#   'attributes': 'Excitement, Suspense, Thrill, Action, Adventure, Intensity, Tension, Anticipation'},
#  'Terminator 2: Judgment Day': {'movie_id': 103064,
#   'year': 1991,
#   'genres': 'Action,Sci-Fi',
#   'average_rating': 8.6,
#   'num_votes': 1132900,
#   'attributes': 'Excitement, Suspense, Thrilling, Intense, Action-packed, Adrenaline-pumping, Engaging, Gripping'},
#  'The Truman Show': {'movie_id': 120382,
#   'year': 1998,
#   'genres': 'Comedy,Drama',
#   'average_rating': 8.2,
#   'num_votes': 1131006,
#   'attributes': 'Excitement, Intrigue, Suspense, Surprise, Amusement, Reflection, Empathy, Curiosity'},
#  'The Usual Suspects': {'movie_id': 114814,
#   'year': 1995,
#   'genres': 'Crime,Drama,Mystery',
#   'average_rating': 8.5,
#   'num_votes': 1111601,
#   'attributes': 'Excitement, Suspense, Intrigue, Tension, Surprise, Curiosity, Suspicion, Thrill'},
#  'The Lion King': {'movie_id': 6105098,
#   'year': 2019,
#   'genres': 'Adventure,Animation,Drama',
#   'average_rating': 6.8,
#   'num_votes': 256956,
#   'attributes': 'excitement, joy, sadness, fear, anticipation, wonder, inspiration, nostalgia'},
#  'Iron Man': {'movie_id': 371746,
#   'year': 2008,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.9,
#   'num_votes': 1090596,
#   'attributes': 'Excitement, Thrill, Suspense, Adventure, Action, Inspiration, Innovation, Heroism'},
#  'Star Wars: Episode VI - Return of the Jedi': {'movie_id': 86190,
#   'year': 1983,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 8.3,
#   'num_votes': 1085814,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Hope, Redemption, Courage, Determination'},
#  'Up': {'movie_id': 1049413,
#   'year': 2009,
#   'genres': 'Adventure,Animation,Comedy',
#   'average_rating': 8.3,
#   'num_votes': 1080477,
#   'attributes': 'Excitement, Joy, Adventure, Amusement, Inspiration, Nostalgia, Wonder, Happiness'},
#  'Deadpool': {'movie_id': 1431045,
#   'year': 2016,
#   'genres': 'Action,Comedy',
#   'average_rating': 8.0,
#   'num_votes': 1078376,
#   'attributes': 'Excitement, Humor, Thrill, Amusement, Entertainment, Fun, Laughter, Enjoyment'},
#  'Finding Nemo': {'movie_id': 266543,
#   'year': 2003,
#   'genres': 'Adventure,Animation,Comedy',
#   'average_rating': 8.2,
#   'num_votes': 1075380,
#   'attributes': 'Excitement, Joy, Amazement, Tenderness, Laughter, Hope, Adventure, Wonder'},
#  'Braveheart': {'movie_id': 112573,
#   'year': 1995,
#   'genres': 'Biography,Drama,History',
#   'average_rating': 8.3,
#   'num_votes': 1061952,
#   'attributes': 'Excitement, Inspiration, Courage, Determination, Patriotism, Defiance, Triumph, Resilience'},
#  'The Shining': {'movie_id': 81505,
#   'year': 1980,
#   'genres': 'Drama,Horror',
#   'average_rating': 8.4,
#   'num_votes': 1059165,
#   'attributes': 'suspense, fear, terror, anxiety, unease, dread, tension, paranoia'},
#  'Reservoir Dogs': {'movie_id': 105236,
#   'year': 1992,
#   'genres': 'Crime,Thriller',
#   'average_rating': 8.3,
#   'num_votes': 1051103,
#   'attributes': 'Excitement, Suspense, Tension, Intrigue, Suspicion, Fear, Paranoia, Uncertainty'},
#  'Mad Max: Fury Road': {'movie_id': 1392190,
#   'year': 2015,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 8.1,
#   'num_votes': 1039200,
#   'attributes': 'Excitement, Thrill, Intensity, Suspense, Empowerment, Determination, Rebellion, Adventure'},
#  'Eternal Sunshine of the Spotless Mind': {'movie_id': 338013,
#   'year': 2004,
#   'genres': 'Drama,Romance,Sci-Fi',
#   'average_rating': 8.3,
#   'num_votes': 1038808,
#   'attributes': 'romantic, nostalgic, bittersweet, thought-provoking, melancholic, introspective, surreal, dreamlike'},
#  "One Flew Over the Cuckoo's Nest": {'movie_id': 73486,
#   'year': 1975,
#   'genres': 'Drama',
#   'average_rating': 8.7,
#   'num_votes': 1036182,
#   'attributes': 'excitement, suspense, fear, empathy, hope, rebellion, triumph, inspiration'},
#  'Catch Me If You Can': {'movie_id': 264464,
#   'year': 2002,
#   'genres': 'Biography,Crime,Drama',
#   'average_rating': 8.1,
#   'num_votes': 1034895,
#   'attributes': 'Excitement, Intrigue, Suspense, Thrill, Fascination, Curiosity, Tension, Anticipation'},
#  'Toy Story': {'movie_id': 114709,
#   'year': 1995,
#   'genres': 'Adventure,Animation,Comedy',
#   'average_rating': 8.3,
#   'num_votes': 1028275,
#   'attributes': 'Excitement, Joy, Amusement, Thrill, Delight, Laughter, Happiness, Anticipation'},
#  'Jurassic Park': {'movie_id': 107290,
#   'year': 1993,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 8.2,
#   'num_votes': 1024847,
#   'attributes': 'Excitement, Thrill, Suspense, Adventure, Wonder, Amazement, Fear, Tension'},
#  'Gone Girl': {'movie_id': 2267998,
#   'year': 2014,
#   'genres': 'Drama,Mystery,Thriller',
#   'average_rating': 8.1,
#   'num_votes': 1018467,
#   'attributes': 'suspense, intrigue, suspicion, tension, fear, uncertainty, surprise, anticipation'},
#  'The Sixth Sense': {'movie_id': 167404,
#   'year': 1999,
#   'genres': 'Drama,Mystery,Thriller',
#   'average_rating': 8.2,
#   'num_votes': 1017652,
#   'attributes': 'Suspense, Intrigue, Fear, Tension, Surprise, Curiosity, Uncertainty, Anticipation'},
#  'Good Will Hunting': {'movie_id': 119217,
#   'year': 1997,
#   'genres': 'Drama,Romance',
#   'average_rating': 8.3,
#   'num_votes': 1013384,
#   'attributes': 'Inspiration, Hope, Determination, Reflection, Growth, Discovery, Love, Self-discovery'},
#  'No Country for Old Men': {'movie_id': 477348,
#   'year': 2007,
#   'genres': 'Crime,Drama,Thriller',
#   'average_rating': 8.2,
#   'num_votes': 1012070,
#   'attributes': 'Suspense, Tension, Fear, Intrigue, Intensity, Unease, Nervousness, Dread'},
#  'Raiders of the Lost Ark': {'movie_id': 82971,
#   'year': 1981,
#   'genres': 'Action,Adventure',
#   'average_rating': 8.4,
#   'num_votes': 1005577,
#   'attributes': 'Excitement, Thrill, Adventure, Suspense, Action, Wonder, Intrigue, Amazement'},
#  'A Beautiful Mind': {'movie_id': 268978,
#   'year': 2001,
#   'genres': 'Biography,Drama',
#   'average_rating': 8.2,
#   'num_votes': 956555,
#   'attributes': 'Excitement, Intrigue, Suspense, Inspiration, Reflection, Tension, Hope, Curiosity'},
#  'The Hunger Games': {'movie_id': 1392170,
#   'year': 2012,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.2,
#   'num_votes': 955056,
#   'attributes': 'Excitement, suspense, fear, anticipation, courage, survival, sacrifice, determination'},
#  'Star Wars: Episode VII - The Force Awakens': {'movie_id': 2488496,
#   'year': 2015,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.8,
#   'num_votes': 952078,
#   'attributes': 'Excitement, Suspense, Adventure, Thrill, Hope, Wonder, Amazement, Anticipation'},
#  'Monsters, Inc.': {'movie_id': 198781,
#   'year': 2001,
#   'genres': 'Adventure,Animation,Comedy',
#   'average_rating': 8.1,
#   'num_votes': 941034,
#   'attributes': 'Excitement, Joy, Surprise, Laughter, Amusement, Delight, Fascination, Wonder'},
#  'Whiplash': {'movie_id': 2582802,
#   'year': 2014,
#   'genres': 'Drama,Music',
#   'average_rating': 8.5,
#   'num_votes': 918579,
#   'attributes': 'Intense, Passionate, Inspiring, Determined, Ambitious, Thrilling, Challenging, Motivating'},
#  'Alien': {'movie_id': 78748,
#   'year': 1979,
#   'genres': 'Horror,Sci-Fi',
#   'average_rating': 8.5,
#   'num_votes': 911241,
#   'attributes': 'Excitement, Suspense, Fear, Tension, Thrill, Intrigue, Dread, Surprise'},
#  'Harry Potter and the Deathly Hallows: Part 2': {'movie_id': 1201607,
#   'year': 2011,
#   'genres': 'Adventure,Family,Fantasy',
#   'average_rating': 8.1,
#   'num_votes': 909078,
#   'attributes': 'Excitement, Tension, Thrill, Suspense, Adventure, Wonder, Anticipation, Amazement'},
#  'Die Hard': {'movie_id': 95016,
#   'year': 1988,
#   'genres': 'Action,Thriller',
#   'average_rating': 8.2,
#   'num_votes': 907256,
#   'attributes': 'Excitement, Suspense, Tension, Adrenaline, Intensity, Thrill, Action-packed, Nerve-racking'},
#  'The Terminator': {'movie_id': 88247,
#   'year': 1984,
#   'genres': 'Action,Sci-Fi',
#   'average_rating': 8.1,
#   'num_votes': 893272,
#   'attributes': 'Excitement, Suspense, Thrill, Fear, Tension, Intensity, Anticipation, Adrenaline'},
#  'Avengers: Age of Ultron': {'movie_id': 2395427,
#   'year': 2015,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.3,
#   'num_votes': 892756,
#   'attributes': 'Excitement, Suspense, Thrilling, Intense, Action-packed, Adrenaline-fueled, Epic, Engaging'},
#  'The Intouchables': {'movie_id': 1675434,
#   'year': 2011,
#   'genres': 'Biography,Comedy,Drama',
#   'average_rating': 8.5,
#   'num_votes': 889521,
#   'attributes': 'Humor, Inspiration, Heartwarming, Joy, Laughter, Hope, Friendship, Empathy'},
#  'The Martian': {'movie_id': 3659388,
#   'year': 2015,
#   'genres': 'Adventure,Drama,Sci-Fi',
#   'average_rating': 8.0,
#   'num_votes': 886727,
#   'attributes': 'Excitement, Suspense, Inspiration, Hope, Determination, Survival, Curiosity, Resilience'},
#  'Snatch': {'movie_id': 208092,
#   'year': 2000,
#   'genres': 'Comedy,Crime',
#   'average_rating': 8.2,
#   'num_votes': 880051,
#   'attributes': 'Excitement, Suspense, Humor, Action, Thrill, Intrigue, Surprise, Adventure'},
#  'Thor': {'movie_id': 800369,
#   'year': 2011,
#   'genres': 'Action,Fantasy',
#   'average_rating': 7.0,
#   'num_votes': 875458,
#   'attributes': 'Excitement, Thrilling, Adventure, Suspense, Epic, Intense, Marvelous, Captivating'},
#  'Scarface': {'movie_id': 86250,
#   'year': 1983,
#   'genres': 'Crime,Drama',
#   'average_rating': 8.3,
#   'num_votes': 875292,
#   'attributes': 'Excitement, suspense, intensity, ambition, power, temptation, corruption, desire'},
#  'Iron Man 3': {'movie_id': 1300854,
#   'year': 2013,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.1,
#   'num_votes': 875281,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Intensity, Intrigue, Action, Revenge'},
#  'Taxi Driver': {'movie_id': 75314,
#   'year': 1976,
#   'genres': 'Crime,Drama',
#   'average_rating': 8.2,
#   'num_votes': 874702,
#   'attributes': 'Thrilling, Intense, Disturbing, Gritty, Dark, Tense, Thought-provoking, Suspenseful'},
#  'Captain America: The Winter Soldier': {'movie_id': 1843866,
#   'year': 2014,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.8,
#   'num_votes': 873394,
#   'attributes': 'Excitement, Suspense, Thrill, Intensity, Intrigue, Tension, Adrenaline, Surprise'},
#  'Parasite': {'movie_id': 6751668,
#   'year': 2019,
#   'genres': 'Drama,Thriller',
#   'average_rating': 8.5,
#   'num_votes': 871490,
#   'attributes': 'suspense, tension, greed, discrimination, wealth, poverty, symbiotic, destitution'},
#  'Captain America: The First Avenger': {'movie_id': 458339,
#   'year': 2011,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 6.9,
#   'num_votes': 871079,
#   'attributes': 'Excitement, Suspense, Thrill, Inspiration, Courage, Patriotism, Determination, Hope'},
#  'Requiem for a Dream': {'movie_id': 180093,
#   'year': 2000,
#   'genres': 'Drama',
#   'average_rating': 8.3,
#   'num_votes': 868048,
#   'attributes': 'Excitement, Suspense, Tension, Desperation, Fear, Hopelessness, Intensity, Anxiety'},
#  'The Pianist': {'movie_id': 253474,
#   'year': 2002,
#   'genres': 'Biography,Drama,Music',
#   'average_rating': 8.5,
#   'num_votes': 866117,
#   'attributes': 'Determined, Resilient, Heartbreaking, Inspiring, Melancholic, Intense, Gripping, Poignant'},
#  'Toy Story 3': {'movie_id': 435761,
#   'year': 2010,
#   'genres': 'Adventure,Animation,Comedy',
#   'average_rating': 8.3,
#   'num_votes': 862817,
#   'attributes': 'Excitement, Joy, Nostalgia, Friendship, Hope, Laughter, Warmth, Adventure'},
#  'Slumdog Millionaire': {'movie_id': 1010048,
#   'year': 2008,
#   'genres': 'Crime,Drama,Romance',
#   'average_rating': 8.0,
#   'num_votes': 861776,
#   'attributes': 'excitement, suspense, love, determination, hope, resilience, nostalgia, triumph'},
#  'A Clockwork Orange': {'movie_id': 66921,
#   'year': 1971,
#   'genres': 'Crime,Sci-Fi',
#   'average_rating': 8.3,
#   'num_votes': 853828,
#   'attributes': 'excitement, suspense, fear, intrigue, curiosity, shock, unease, anticipation'},
#  'The Grand Budapest Hotel': {'movie_id': 2278388,
#   'year': 2014,
#   'genres': 'Adventure,Comedy,Crime',
#   'average_rating': 8.1,
#   'num_votes': 848956,
#   'attributes': 'Excitement, Humor, Intrigue, Nostalgia, Suspense, Joy, Amusement, Fascination'},
#  'The Hobbit: An Unexpected Journey': {'movie_id': 903624,
#   'year': 2012,
#   'genres': 'Adventure,Fantasy',
#   'average_rating': 7.8,
#   'num_votes': 848328,
#   'attributes': 'Excitement, Adventure, Thrilling, Suspenseful, Magical, Enchanting, Epic, Heartwarming'},
#  'Spider-Man': {'movie_id': 145487,
#   'year': 2002,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.4,
#   'num_votes': 847139,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Empowerment, Hope, Determination, Revenge'},
#  'Gravity': {'movie_id': 1454468,
#   'year': 2013,
#   'genres': 'Drama,Sci-Fi,Thriller',
#   'average_rating': 7.7,
#   'num_votes': 844242,
#   'attributes': 'Excitement, Suspense, Tension, Fear, Adrenaline, Intensity, Nervousness, Anticipation'},
#  'Iron Man 2': {'movie_id': 1228705,
#   'year': 2010,
#   'genres': 'Action,Sci-Fi',
#   'average_rating': 6.9,
#   'num_votes': 843215,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Intrigue, Action, Amazement, Inspiration'},
#  '300': {'movie_id': 416449,
#   'year': 2006,
#   'genres': 'Action,Drama',
#   'average_rating': 7.6,
#   'num_votes': 841667,
#   'attributes': 'Excitement, Intensity, Courage, Determination, Patriotism, Heroism, Sacrifice, Resilience'},
#  'The Revenant': {'movie_id': 1663202,
#   'year': 2015,
#   'genres': 'Action,Adventure,Drama',
#   'average_rating': 8.0,
#   'num_votes': 835296,
#   'attributes': 'excitement, suspense, fear, determination, resilience, survival, revenge, intensity'},
#  'The Big Lebowski': {'movie_id': 118715,
#   'year': 1998,
#   'genres': 'Comedy,Crime',
#   'average_rating': 8.1,
#   'num_votes': 832730,
#   'attributes': 'Excitement, Humor, Suspense, Thrill, Relaxation, Amusement, Surprise, Satisfaction'},
#  'Star Wars: Episode I - The Phantom Menace': {'movie_id': 120915,
#   'year': 1999,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 6.5,
#   'num_votes': 830198,
#   'attributes': 'Excitement, Suspense, Adventure, Thrilling, Epic, Action-packed, Intense, Surprising'},
#  'Donnie Darko': {'movie_id': 246578,
#   'year': 2001,
#   'genres': 'Drama,Mystery,Sci-Fi',
#   'average_rating': 8.0,
#   'num_votes': 824680,
#   'attributes': 'The emotions for the movie "Donnie Darko" are: confusion, fear, intrigue, suspense, curiosity, unease, fascination, anticipation'},
#  '12 Angry Men': {'movie_id': 50083,
#   'year': 1957,
#   'genres': 'Crime,Drama',
#   'average_rating': 9.0,
#   'num_votes': 822751,
#   'attributes': 'suspenseful, intense, thought-provoking, gripping, compelling, dramatic, engaging, intriguing'},
#  'Captain America: Civil War': {'movie_id': 3498820,
#   'year': 2016,
#   'genres': 'Action,Sci-Fi',
#   'average_rating': 7.8,
#   'num_votes': 819508,
#   'attributes': 'Excitement, Suspense, Thrilling, Intense, Dramatic, Emotional, Tense, Action-packed'},
#  'Star Wars: Episode III - Revenge of the Sith': {'movie_id': 121766,
#   'year': 2005,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 7.6,
#   'num_votes': 817671,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Action, Fantasy, Intrigue, Drama'},
#  "Harry Potter and the Sorcerer's Stone": {'movie_id': 241527,
#   'year': 2001,
#   'genres': 'Adventure,Family,Fantasy',
#   'average_rating': 7.6,
#   'num_votes': 816877,
#   'attributes': 'Excitement, Wonder, Adventure, Mystery, Thrill, Magic, Friendship, Courage'},
#  'Spider-Man: No Way Home': {'movie_id': 10872600,
#   'year': 2021,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 8.2,
#   'num_votes': 816738,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Wonder, Amazement, Anticipation, Surprise'},
#  'The Hangover': {'movie_id': 1119646,
#   'year': 2009,
#   'genres': 'Comedy',
#   'average_rating': 7.7,
#   'num_votes': 814535,
#   'attributes': 'Excitement, Hilarity, Amusement, Surprise, Anticipation, Joy, Satisfaction, Thrill'},
#  'Black Panther': {'movie_id': 1825683,
#   'year': 2018,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.3,
#   'num_votes': 808855,
#   'attributes': 'Excitement, Thrill, Suspense, Inspiration, Empowerment, Pride, Hope, Anticipation'},
#  'Spirited Away': {'movie_id': 245429,
#   'year': 2001,
#   'genres': 'Adventure,Animation,Family',
#   'average_rating': 8.6,
#   'num_votes': 800130,
#   'attributes': 'Excitement, Wonder, Curiosity, Amazement, Fear, Joy, Fascination, Intrigue'},
#  'Logan': {'movie_id': 3315342,
#   'year': 2017,
#   'genres': 'Action,Drama,Sci-Fi',
#   'average_rating': 8.1,
#   'num_votes': 796243,
#   'attributes': 'Excitement, Suspense, Tension, Empathy, Hope, Fear, Intrigue, Inspiration'},
#  'The Imitation Game': {'movie_id': 2084970,
#   'year': 2014,
#   'genres': 'Biography,Drama,Thriller',
#   'average_rating': 8.0,
#   'num_votes': 795217,
#   'attributes': 'Excitement, Suspense, Intrigue, Tension, Curiosity, Inspiration, Reflection, Empathy'},
#  'Blade Runner': {'movie_id': 83658,
#   'year': 1982,
#   'genres': 'Action,Drama,Sci-Fi',
#   'average_rating': 8.1,
#   'num_votes': 794444,
#   'attributes': 'Excitement, Suspense, Intrigue, Tension, Wonder, Amazement, Curiosity, Fascination'},
#  'Black Swan': {'movie_id': 947798,
#   'year': 2010,
#   'genres': 'Drama,Thriller',
#   'average_rating': 8.0,
#   'num_votes': 794207,
#   'attributes': 'intense, suspenseful, psychological, haunting, disturbing, captivating, thrilling, dark'},
#  'Gran Torino': {'movie_id': 1205489,
#   'year': 2008,
#   'genres': 'Drama',
#   'average_rating': 8.1,
#   'num_votes': 793995,
#   'attributes': 'Excitement, Tension, Empathy, Inspiration, Nostalgia, Hope, Reflection, Satisfaction'},
#  'Man of Steel': {'movie_id': 770828,
#   'year': 2013,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.1,
#   'num_votes': 792368,
#   'attributes': 'Excitement, Suspense, Thrilling, Intense, Adrenaline, Heroism, Hope, Determination'},
#  'Once Upon a Time in Hollywood': {'movie_id': 7131622,
#   'year': 2019,
#   'genres': 'Comedy,Drama',
#   'average_rating': 7.6,
#   'num_votes': 788734,
#   'attributes': 'excitement, nostalgia, anticipation, humor, joy, admiration, curiosity, satisfaction'},
#  'Indiana Jones and the Last Crusade': {'movie_id': 97576,
#   'year': 1989,
#   'genres': 'Action,Adventure',
#   'average_rating': 8.2,
#   'num_votes': 785660,
#   'attributes': 'Excitement, Suspense, Thrilling, Adventure, Action, Intrigue, Fascination, Tension'},
#  'I Am Legend': {'movie_id': 480249,
#   'year': 2007,
#   'genres': 'Action,Drama,Horror',
#   'average_rating': 7.2,
#   'num_votes': 785493,
#   'attributes': 'Excitement, Suspense, Fear, Tension, Hope, Loneliness, Survival, Desperation'},
#  'Thor: Ragnarok': {'movie_id': 3501632,
#   'year': 2017,
#   'genres': 'Action,Adventure,Comedy',
#   'average_rating': 7.9,
#   'num_votes': 784422,
#   'attributes': 'Excitement, Adventure, Humor, Thrill, Suspense, Action, Amusement, Joy'},
#  'The Good, the Bad and the Ugly': {'movie_id': 60196,
#   'year': 1966,
#   'genres': 'Adventure,Western',
#   'average_rating': 8.8,
#   'num_votes': 783444,
#   'attributes': 'excitement, suspense, tension, thrill, anticipation, adventure, intrigue, mystery'},
#  'Sin City': {'movie_id': 401792,
#   'year': 2005,
#   'genres': 'Crime,Thriller',
#   'average_rating': 8.0,
#   'num_votes': 781623,
#   'attributes': 'Excitement, Suspense, Intensity, Intrigue, Tension, Drama, Gritty, Dark'},
#  'Kill Bill: Vol. 2': {'movie_id': 378194,
#   'year': 2004,
#   'genres': 'Action,Crime,Thriller',
#   'average_rating': 8.0,
#   'num_votes': 778897,
#   'attributes': 'Excitement, Suspense, Revenge, Intensity, Tension, Thrill, Intrigue, Drama'},
#  'Ratatouille': {'movie_id': 382932,
#   'year': 2007,
#   'genres': 'Adventure,Animation,Comedy',
#   'average_rating': 8.1,
#   'num_votes': 777569,
#   'attributes': 'Excitement, Joy, Amusement, Inspiration, Delight, Fascination, Satisfaction, Warmth'},
#  'City of God': {'movie_id': 317248,
#   'year': 2002,
#   'genres': 'Crime,Drama',
#   'average_rating': 8.6,
#   'num_votes': 776300,
#   'attributes': 'Excitement, Suspense, Tension, Thrill, Intensity, Intrigue, Drama, Passion'},
#  'Amélie': {'movie_id': 211915,
#   'year': 2001,
#   'genres': 'Comedy,Romance',
#   'average_rating': 8.3,
#   'num_votes': 773804,
#   'attributes': 'Joy, Love, Happiness, Imagination, Romance, Comedy, Adventure, Inspiration'},
#  'Doctor Strange': {'movie_id': 1211837,
#   'year': 2016,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 7.5,
#   'num_votes': 773266,
#   'attributes': 'Excitement, Intrigue, Wonder, Thrill, Suspense, Amazement, Curiosity, Fascination'},
#  'The Incredibles': {'movie_id': 317705,
#   'year': 2004,
#   'genres': 'Action,Adventure,Animation',
#   'average_rating': 8.0,
#   'num_votes': 770904,
#   'attributes': 'Excitement, Thrill, Adventure, Suspense, Humor, Family, Heroism, Action'},
#  'How to Train Your Dragon': {'movie_id': 892769,
#   'year': 2010,
#   'genres': 'Action,Adventure,Animation',
#   'average_rating': 8.1,
#   'num_votes': 768735,
#   'attributes': 'Excitement, Adventure, Friendship, Surprises, Courage, Wonder, Amazement, Joy'},
#  'Full Metal Jacket': {'movie_id': 93058,
#   'year': 1987,
#   'genres': 'Drama,War',
#   'average_rating': 8.3,
#   'num_votes': 764531,
#   'attributes': 'intense, gritty, emotional, thought-provoking, disturbing, intense, suspenseful, powerful'},
#  'Prisoners': {'movie_id': 1392214,
#   'year': 2013,
#   'genres': 'Crime,Drama,Mystery',
#   'average_rating': 8.1,
#   'num_votes': 758495,
#   'attributes': 'suspense, tension, fear, anxiety, uncertainty, desperation, frustration, anticipation'},
#  'Inside Out': {'movie_id': 2096673,
#   'year': 2015,
#   'genres': 'Adventure,Animation,Comedy',
#   'average_rating': 8.1,
#   'num_votes': 745679,
#   'attributes': 'Joy, Fear, Anger, Disgust, Sadness'},
#  "Pirates of the Caribbean: Dead Man's Chest": {'movie_id': 383574,
#   'year': 2006,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 7.4,
#   'num_votes': 742228,
#   'attributes': 'excitement, suspense, adventure, humor, thrill, anticipation, surprise, awe'},
#  'Aliens': {'movie_id': 90605,
#   'year': 1986,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 8.4,
#   'num_votes': 738025,
#   'attributes': 'Excitement, Suspense, Fear, Thrill, Intensity, Tension, Adrenaline, Dread'},
#  'Star Wars: Episode II - Attack of the Clones': {'movie_id': 121765,
#   'year': 2002,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 6.6,
#   'num_votes': 734535,
#   'attributes': 'Excitement, Suspense, Romance, Adventure, Intrigue, Thrilling, Fantasy, Action'},
#  'Knives Out': {'movie_id': 8946378,
#   'year': 2019,
#   'genres': 'Comedy,Crime,Drama',
#   'average_rating': 7.9,
#   'num_votes': 734214,
#   'attributes': 'excitement, suspense, intrigue, humor, surprise, curiosity, tension, amusement'},
#  'The Social Network': {'movie_id': 1285016,
#   'year': 2010,
#   'genres': 'Biography,Drama',
#   'average_rating': 7.8,
#   'num_votes': 729275,
#   'attributes': 'Thrilling, Inspiring, Intense, Suspenseful, Thought-provoking, Captivating, Emotional, Gripping'},
#  'X-Men: Days of Future Past': {'movie_id': 1877832,
#   'year': 2014,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.9,
#   'num_votes': 728935,
#   'attributes': 'Excitement, Suspense, Thrill, Tension, Anticipation, Adventure, Hope, Determination'},
#  'Arrival': {'movie_id': 2543164,
#   'year': 2016,
#   'genres': 'Drama,Mystery,Sci-Fi',
#   'average_rating': 7.9,
#   'num_votes': 727361,
#   'attributes': 'Excitement, Intrigue, Suspense, Curiosity, Wonder, Amazement, Tension, Anticipation'},
#  'Guardians of the Galaxy Vol. 2': {'movie_id': 3896198,
#   'year': 2017,
#   'genres': 'Action,Adventure,Comedy',
#   'average_rating': 7.6,
#   'num_votes': 725970,
#   'attributes': 'Excitement, Amusement, Adventure, Happiness, Thrill, Fun, Entertainment, Joy'},
#  'Silver Linings Playbook': {'movie_id': 1045658,
#   'year': 2012,
#   'genres': 'Comedy,Drama,Romance',
#   'average_rating': 7.7,
#   'num_votes': 725299,
#   'attributes': 'happy, hopeful, heartwarming, uplifting, inspiring, romantic, bittersweet, charming'},
#  '12 Years a Slave': {'movie_id': 2024544,
#   'year': 2013,
#   'genres': 'Biography,Drama,History',
#   'average_rating': 8.1,
#   'num_votes': 720374,
#   'attributes': 'Drama, Intense, Gripping, Emotional, Powerful, Heartbreaking, Thought-provoking, Inspiring'},
#  'Batman v Superman: Dawn of Justice': {'movie_id': 2975590,
#   'year': 2016,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 6.4,
#   'num_votes': 716741,
#   'attributes': 'Excitement, Suspense, Thrilling, Intense, Intrigue, Tension, Adrenaline, Anticipation'},
#  'Life Is Beautiful': {'movie_id': 118799,
#   'year': 1997,
#   'genres': 'Comedy,Drama,Romance',
#   'average_rating': 8.6,
#   'num_votes': 716690,
#   'attributes': 'hope, love, resilience, humor, imagination, fear, sadness, courage'},
#  'The Batman': {'movie_id': 1877830,
#   'year': 2022,
#   'genres': 'Action,Crime,Drama',
#   'average_rating': 7.8,
#   'num_votes': 714531,
#   'attributes': 'Excitement, Suspense, Intrigue, Tension, Thrill, Intensity, Mystery, Curiosity'},
#  'Skyfall': {'movie_id': 1074638,
#   'year': 2012,
#   'genres': 'Action,Adventure,Thriller',
#   'average_rating': 7.8,
#   'num_votes': 713553,
#   'attributes': 'Excitement, Suspense, Intrigue, Tension, Thrill, Intensity, Adrenaline, Anticipation'},
#  'X-Men: First Class': {'movie_id': 1270798,
#   'year': 2011,
#   'genres': 'Action,Sci-Fi',
#   'average_rating': 7.7,
#   'num_votes': 708421,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Intrigue, Tension, Drama, Conflict'},
#  'John Wick': {'movie_id': 2911666,
#   'year': 2014,
#   'genres': 'Action,Crime,Thriller',
#   'average_rating': 7.4,
#   'num_votes': 706373,
#   'attributes': 'Excitement, Suspense, Intensity, Revenge, Determination, Grit, Tension, Vengeance'},
#  'Edge of Tomorrow': {'movie_id': 1631867,
#   'year': 2014,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.9,
#   'num_votes': 706088,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Intensity, Intrigue, Amazement, Anticipation'},
#  'Shrek': {'movie_id': 126029,
#   'year': 2001,
#   'genres': 'Adventure,Animation,Comedy',
#   'average_rating': 7.9,
#   'num_votes': 705561,
#   'attributes': 'Excitement, Humor, Adventure, Joy, Amusement, Fun, Entertainment, Happiness'},
#  'Trainspotting': {'movie_id': 117951,
#   'year': 1996,
#   'genres': 'Drama',
#   'average_rating': 8.1,
#   'num_votes': 705199,
#   'attributes': 'Excitement, Intrigue, Suspense, Intensity, Tension, Thrill, Fascination, Intricacy'},
#  'Thor: The Dark World': {'movie_id': 1981115,
#   'year': 2013,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 6.8,
#   'num_votes': 704571,
#   'attributes': 'Excitement, Suspense, Adventure, Thrilling, Intensity, Heroism, Courage, Tension'},
#  'Million Dollar Baby': {'movie_id': 405159,
#   'year': 2004,
#   'genres': 'Drama,Sport',
#   'average_rating': 8.1,
#   'num_votes': 703636,
#   'attributes': 'determined, inspiring, heartwarming, intense, emotional, uplifting, bittersweet, powerful'},
#  'Suicide Squad': {'movie_id': 1386697,
#   'year': 2016,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 5.9,
#   'num_votes': 703585,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Action, Fantasy, Intrigue, Intensity'},
#  'Ant-Man': {'movie_id': 478970,
#   'year': 2015,
#   'genres': 'Action,Comedy,Sci-Fi',
#   'average_rating': 7.3,
#   'num_votes': 698882,
#   'attributes': 'Excitement, Humor, Adventure, Thrill, Suspense, Amusement, Entertainment, Joy'},
#  'District 9': {'movie_id': 1136608,
#   'year': 2009,
#   'genres': 'Action,Sci-Fi,Thriller',
#   'average_rating': 7.9,
#   'num_votes': 698679,
#   'attributes': 'Excitement, Suspense, Tension, Fear, Curiosity, Intrigue, Amazement, Empathy'},
#  'Dune': {'movie_id': 1160419,
#   'year': 2021,
#   'genres': 'Action,Adventure,Drama',
#   'average_rating': 8.0,
#   'num_votes': 697622,
#   'attributes': 'Excitement, Suspense, Intrigue, Tension, Anticipation, Wonder, Fear, Hope'},
#  'Fargo': {'movie_id': 116282,
#   'year': 1996,
#   'genres': 'Crime,Thriller',
#   'average_rating': 8.1,
#   'num_votes': 697443,
#   'attributes': 'Excitement, Suspense, Tension, Intrigue, Surprise, Curiosity, Anticipation, Satisfaction'},
#  'Dunkirk': {'movie_id': 5013056,
#   'year': 2017,
#   'genres': 'Action,Drama,History',
#   'average_rating': 7.8,
#   'num_votes': 694568,
#   'attributes': 'Excitement, Tension, Suspense, Fear, Heroism, Hope, Resilience, Triumph'},
#  "The King's Speech": {'movie_id': 1504320,
#   'year': 2010,
#   'genres': 'Biography,Drama,History',
#   'average_rating': 8.0,
#   'num_votes': 694404,
#   'attributes': 'Confident, Inspirational, Heartwarming, Moving, Empowering, Courageous, Triumphant, Motivating'},
#  'Psycho': {'movie_id': 54215,
#   'year': 1960,
#   'genres': 'Horror,Mystery,Thriller',
#   'average_rating': 8.5,
#   'num_votes': 693163,
#   'attributes': 'Suspense, Fear, Tension, Intrigue, Anxiety, Paranoia, Dread, Unease'},
#  'World War Z': {'movie_id': 816711,
#   'year': 2013,
#   'genres': 'Action,Adventure,Horror',
#   'average_rating': 7.0,
#   'num_votes': 692691,
#   'attributes': 'Excitement, Suspense, Fear, Tension, Thrill, Intensity, Dread, Anxiety'},
#  'Kingsman: The Secret Service': {'movie_id': 2802144,
#   'year': 2014,
#   'genres': 'Action,Adventure,Comedy',
#   'average_rating': 7.7,
#   'num_votes': 692307,
#   'attributes': 'Excitement, Thrill, Humor, Suspense, Adventure, Action, Entertainment, Amusement'},
#  '2001: A Space Odyssey': {'movie_id': 62622,
#   'year': 1968,
#   'genres': 'Adventure,Sci-Fi',
#   'average_rating': 8.3,
#   'num_votes': 691412,
#   'attributes': 'excitement, curiosity, awe, suspense, wonder, intrigue, fascination, anticipation'},
#  'Spider-Man: Homecoming': {'movie_id': 2250912,
#   'year': 2017,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.4,
#   'num_votes': 688739,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Amazement, Wonder, Anticipation, Surprise'},
#  'The Hunger Games: Catching Fire': {'movie_id': 1951264,
#   'year': 2013,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.5,
#   'num_votes': 688282,
#   'attributes': 'Excitement, Suspense, Thrill, Courage, Determination, Rebellion, Hope, Survival'},
#  'Apocalypse Now': {'movie_id': 78788,
#   'year': 1979,
#   'genres': 'Drama,Mystery,War',
#   'average_rating': 8.4,
#   'num_votes': 687033,
#   'attributes': 'Intense, Suspenseful, Thought-provoking, Disturbing, Gritty, Tense, Emotional, Gripping'},
#  "Pan's Labyrinth": {'movie_id': 457430,
#   'year': 2006,
#   'genres': 'Drama,Fantasy,War',
#   'average_rating': 8.2,
#   'num_votes': 684810,
#   'attributes': 'captivating, eerie, fantasy, war, dramatic, intense, suspenseful, thrilling'},
#  'Heat': {'movie_id': 113277,
#   'year': 1995,
#   'genres': 'Action,Crime,Drama',
#   'average_rating': 8.3,
#   'num_votes': 684588,
#   'attributes': 'Excitement, Suspense, Tension, Thrilling, Intensity, Intrigue, Adrenaline, Nerve-racking'},
#  'Now You See Me': {'movie_id': 1670345,
#   'year': 2013,
#   'genres': 'Crime,Mystery,Thriller',
#   'average_rating': 7.2,
#   'num_votes': 683585,
#   'attributes': 'Excitement, Suspense, Intrigue, Surprise, Amazement, Tension, Curiosity, Satisfaction'},
#  'The Hobbit: The Desolation of Smaug': {'movie_id': 1170358,
#   'year': 2013,
#   'genres': 'Adventure,Drama,Fantasy',
#   'average_rating': 7.8,
#   'num_votes': 682959,
#   'attributes': 'Excitement, Suspense, Adventure, Thrilling, Enchanting, Magical, Epic, Mysterious'},
#  'Spider-Man 2': {'movie_id': 316654,
#   'year': 2004,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.4,
#   'num_votes': 680071,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Action, Intrigue, Drama, Inspiration'},
#  'Wonder Woman': {'movie_id': 451279,
#   'year': 2017,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 7.4,
#   'num_votes': 679560,
#   'attributes': 'Excitement, Adventure, Empowerment, Hope, Courage, Determination, Wonder, Inspiration'},
#  'The Amazing Spider-Man': {'movie_id': 948470,
#   'year': 2012,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 6.9,
#   'num_votes': 678800,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Wonder, Amazement, Courage, Determination'},
#  'Casino Royale': {'movie_id': 381061,
#   'year': 2006,
#   'genres': 'Action,Adventure,Thriller',
#   'average_rating': 8.0,
#   'num_votes': 675084,
#   'attributes': 'Excitement, Suspense, Intrigue, Thrill, Adventure, Tension, Action, Anticipation'},
#  'The Curious Case of Benjamin Button': {'movie_id': 421715,
#   'year': 2008,
#   'genres': 'Drama,Fantasy,Romance',
#   'average_rating': 7.8,
#   'num_votes': 672925,
#   'attributes': 'Romantic, Enchanting, Sentimental, Nostalgic, Whimsical, Bittersweet, Thought-provoking, Touching'},
#  'Drive': {'movie_id': 780504,
#   'year': 2011,
#   'genres': 'Action,Drama',
#   'average_rating': 7.8,
#   'num_votes': 672571,
#   'attributes': 'Excitement, Suspense, Thrilling, Intensity, Tension, Intrigue, Adrenaline, Nerve-wracking'},
#  "Pirates of the Caribbean: At World's End": {'movie_id': 449088,
#   'year': 2007,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 7.1,
#   'num_votes': 671765,
#   'attributes': 'Excitement, Adventure, Thrill, Suspense, Action, Wonder, Amazement, Anticipation'},
#  'American Psycho': {'movie_id': 144084,
#   'year': 2000,
#   'genres': 'Crime,Drama,Horror',
#   'average_rating': 7.6,
#   'num_votes': 666255,
#   'attributes': 'excitement, suspense, fear, thrill, intensity, shock, unease, tension'},
#  'Rogue One: A Star Wars Story': {'movie_id': 3748528,
#   'year': 2016,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.8,
#   'num_votes': 662375,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Action, Hope, Determination, Courage'},
#  'Harry Potter and the Chamber of Secrets': {'movie_id': 295297,
#   'year': 2002,
#   'genres': 'Adventure,Family,Fantasy',
#   'average_rating': 7.4,
#   'num_votes': 662292,
#   'attributes': 'Excitement, Suspense, Wonder, Enchantment, Thrill, Fascination, Intrigue, Amazement'},
#  'Jurassic World': {'movie_id': 369610,
#   'year': 2015,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 6.9,
#   'num_votes': 661322,
#   'attributes': 'Excitement, Thrill, Suspense, Adventure, Wonder, Fear, Amazement, Tension'},
#  'Harry Potter and the Prisoner of Azkaban': {'movie_id': 304141,
#   'year': 2004,
#   'genres': 'Adventure,Family,Fantasy',
#   'average_rating': 7.9,
#   'num_votes': 661257,
#   'attributes': 'Excitement, Suspense, Wonder, Thrill, Magic, Friendship, Mystery, Danger'},
#  'Transformers': {'movie_id': 418279,
#   'year': 2007,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 7.0,
#   'num_votes': 659494,
#   'attributes': 'Excitement, Suspense, Thrilling, Action-packed, Intense, Adrenaline-pumping, Engaging, Captivating'},
#  'Groundhog Day': {'movie_id': 107048,
#   'year': 1993,
#   'genres': 'Comedy,Drama,Fantasy',
#   'average_rating': 8.0,
#   'num_votes': 656451,
#   'attributes': 'excitement, humor, reflection, frustration, curiosity, enlightenment, satisfaction, anticipation'},
#  'Harry Potter and the Goblet of Fire': {'movie_id': 330373,
#   'year': 2005,
#   'genres': 'Adventure,Family,Fantasy',
#   'average_rating': 7.7,
#   'num_votes': 652360,
#   'attributes': 'Excitement, Suspense, Thrilling, Enchanting, Magical, Mysterious, Adventurous, Intriguing'},
#  'Star Wars: Episode VIII - The Last Jedi': {'movie_id': 2527336,
#   'year': 2017,
#   'genres': 'Action,Adventure,Fantasy',
#   'average_rating': 6.9,
#   'num_votes': 652087,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Wonder, Surprise, Amazement, Intrigue'},
#  'Sherlock Holmes': {'movie_id': 988045,
#   'year': 2009,
#   'genres': 'Action,Adventure,Mystery',
#   'average_rating': 7.6,
#   'num_votes': 651761,
#   'attributes': 'Excitement, Suspense, Intrigue, Thrill, Curiosity, Tension, Anticipation, Surprise'},
#  'Life of Pi': {'movie_id': 454876,
#   'year': 2012,
#   'genres': 'Adventure,Drama,Fantasy',
#   'average_rating': 7.9,
#   'num_votes': 649112,
#   'attributes': 'excitement, awe, fear, suspense, wonder, hope, loneliness, determination'},
#  'Birdman or (The Unexpected Virtue of Ignorance)': {'movie_id': 2562232,
#   'year': 2014,
#   'genres': 'Comedy,Drama',
#   'average_rating': 7.7,
#   'num_votes': 648930,
#   'attributes': 'Excitement, Intrigue, Suspense, Humor, Inspiration, Reflection, Tension, Satisfaction'},
#  'Get Out': {'movie_id': 5052448,
#   'year': 2017,
#   'genres': 'Horror,Mystery,Thriller',
#   'average_rating': 7.8,
#   'num_votes': 648393,
#   'attributes': 'suspense, tension, uneasiness, fear, curiosity, surprise, anticipation, anxiety'},
#  'The Bourne Ultimatum': {'movie_id': 440963,
#   'year': 2007,
#   'genres': 'Action,Mystery,Thriller',
#   'average_rating': 8.0,
#   'num_votes': 646693,
#   'attributes': 'Excitement, Suspense, Intrigue, Tension, Adrenaline, Mystery, Intensity, Thrill'},
#  'Frozen': {'movie_id': 2294629,
#   'year': 2013,
#   'genres': 'Adventure,Animation,Comedy',
#   'average_rating': 7.4,
#   'num_votes': 643614,
#   'attributes': 'Excitement, Joy, Wonder, Happiness, Amusement, Delight, Warmth, Playfulness'},
#  'Her': {'movie_id': 1798709,
#   'year': 2013,
#   'genres': 'Drama,Romance,Sci-Fi',
#   'average_rating': 8.0,
#   'num_votes': 641810,
# ...
#   'average_rating': 7.4,
#   'num_votes': 234754,
#   'attributes': 'Excitement, Suspense, Fear, Intrigue, Mystery, Tension, Unease, Curiosity'},
#  'Transcendence': {'movie_id': 2209764,
#   'year': 2014,
#   'genres': 'Action,Drama,Sci-Fi',
#   'average_rating': 6.2,
#   'num_votes': 234501,
#   'attributes': 'Excitement, Suspense, Intrigue, Curiosity, Wonder, Tension, Fascination, Amazement'},
#  'Body of Lies': {'movie_id': 758774,
#   'year': 2008,
#   'genres': 'Action,Drama,Thriller',
#   'average_rating': 7.0,
#   'num_votes': 233901,
#   'attributes': 'Excitement, Suspense, Tension, Intrigue, Uncertainty, Intensity, Adrenaline, Nervousness'},
#  'Stranger Than Fiction': {'movie_id': 420223,
#   'year': 2006,
#   'genres': 'Comedy,Drama,Fantasy',
#   'average_rating': 7.5,
#   'num_votes': 233299,
#   'attributes': 'excitement, curiosity, humor, intrigue, suspense, surprise, empathy, satisfaction'},
#  'Uncharted': {'movie_id': 1464335,
#   'year': 2022,
#   'genres': 'Action,Adventure',
#   'average_rating': 6.3,
#   'num_votes': 233225,
#   'attributes': 'Excitement, Thrill, Adventure, Suspense, Intrigue, Action, Curiosity, Anticipation'},
#  'Munich': {'movie_id': 408306,
#   'year': 2005,
#   'genres': 'Action,Drama,History',
#   'average_rating': 7.5,
#   'num_votes': 233095,
#   'attributes': 'Thrilling, Intense, Suspenseful, Emotional, Gripping, Thought-provoking, Tense, Powerful'},
#  'Legally Blonde': {'movie_id': 250494,
#   'year': 2001,
#   'genres': 'Comedy,Romance',
#   'average_rating': 6.4,
#   'num_votes': 232576,
#   'attributes': 'funny, uplifting, empowering, lighthearted, romantic, confident, determined, self-discovery'},
#  'Guardians of the Galaxy Vol. 3': {'movie_id': 6791350,
#   'year': 2023,
#   'genres': 'Action,Adventure,Comedy',
#   'average_rating': 8.1,
#   'num_votes': 232506,
#   'attributes': 'Excitement, Adventure, Humor, Thrill, Suspense, Joy, Amusement, Anticipation'},
#  'The Impossible': {'movie_id': 1649419,
#   'year': 2012,
#   'genres': 'Adventure,Drama,History',
#   'average_rating': 7.5,
#   'num_votes': 232480,
#   'attributes': 'Excitement, Tension, Fear, Hope, Sadness, Relief, Empathy, Inspiration'},
#  'Kiss Kiss Bang Bang': {'movie_id': 373469,
#   'year': 2005,
#   'genres': 'Comedy,Crime,Mystery',
#   'average_rating': 7.5,
#   'num_votes': 232440,
#   'attributes': 'excitement, suspense, humor, intrigue, surprise, curiosity, thrill, amusement'},
#  'The Boy in the Striped Pajamas': {'movie_id': 914798,
#   'year': 2008,
#   'genres': 'Drama,War',
#   'average_rating': 7.7,
#   'num_votes': 232437,
#   'attributes': 'emotional, thought-provoking, heart-wrenching, poignant, intense, shocking, moving, powerful'},
#  'Clueless': {'movie_id': 112697,
#   'year': 1995,
#   'genres': 'Comedy,Romance',
#   'average_rating': 6.9,
#   'num_votes': 232351,
#   'attributes': 'funny, lighthearted, charming, romantic, witty, entertaining, feel-good, enjoyable'},
#  'The Purge': {'movie_id': 2184339,
#   'year': 2013,
#   'genres': 'Horror,Sci-Fi,Thriller',
#   'average_rating': 5.7,
#   'num_votes': 232236,
#   'attributes': 'Suspense, Fear, Tension, Anxiety, Dread, Unease, Nervousness, Apprehension'},
#  'The Northman': {'movie_id': 11138512,
#   'year': 2022,
#   'genres': 'Action,Adventure,Drama',
#   'average_rating': 7.0,
#   'num_votes': 232192,
#   'attributes': 'excitement, suspense, revenge, determination, bravery, tragedy, justice, triumph'},
#  'The Girl Next Door': {'movie_id': 265208,
#   'year': 2004,
#   'genres': 'Comedy,Drama,Romance',
#   'average_rating': 6.7,
#   'num_votes': 232014,
#   'attributes': 'excitement, joy, anticipation, romance, humor, nostalgia, curiosity, happiness'},
#  'Big': {'movie_id': 94737,
#   'year': 1988,
#   'genres': 'Comedy,Drama,Fantasy',
#   'average_rating': 7.3,
#   'num_votes': 231659,
#   'attributes': 'Excitement, Amusement, Wonder, Curiosity, Nostalgia, Inspiration, Joy, Surprise'},
#  "Ocean's Eight": {'movie_id': 5164214,
#   'year': 2018,
#   'genres': 'Action,Comedy,Crime',
#   'average_rating': 6.3,
#   'num_votes': 231559,
#   'attributes': 'Excitement, Humor, Thrill, Suspense, Adventure, Entertainment, Amusement, Intrigue'},
#  'Sleepers': {'movie_id': 117665,
#   'year': 1996,
#   'genres': 'Crime,Drama,Thriller',
#   'average_rating': 7.5,
#   'num_votes': 231379,
#   'attributes': 'Thrilling, Intense, Gripping, Suspenseful, Emotional, Vengeful, Shocking, Powerful'},
#  'Rush Hour 2': {'movie_id': 266915,
#   'year': 2001,
#   'genres': 'Action,Comedy,Crime',
#   'average_rating': 6.7,
#   'num_votes': 230683,
#   'attributes': 'Excitement, Laughter, Suspense, Thrill, Entertainment, Amusement, Fun, Adventure'},
#  'White House Down': {'movie_id': 2334879,
#   'year': 2013,
#   'genres': 'Action,Drama,Thriller',
#   'average_rating': 6.3,
#   'num_votes': 230389,
#   'attributes': 'Excitement, Suspense, Tension, Fear, Adrenaline, Anxiety, Intensity, Nervousness'},
#  'The Great Dictator': {'movie_id': 32553,
#   'year': 1940,
#   'genres': 'Comedy,Drama,War',
#   'average_rating': 8.4,
#   'num_votes': 230367,
#   'attributes': 'Excitement, Humor, Tension, Hope, Sadness, Empathy, Inspiration, Suspense'},
#  'Master and Commander: The Far Side of the World': {'movie_id': 311113,
#   'year': 2003,
#   'genres': 'Action,Adventure,Drama',
#   'average_rating': 7.5,
#   'num_votes': 230278,
#   'attributes': 'Excitement, Suspense, Adventure, Tension, Thrill, Determination, Courage, Intensity'},
#  'I, Tonya': {'movie_id': 5580036,
#   'year': 2017,
#   'genres': 'Biography,Comedy,Drama',
#   'average_rating': 7.5,
#   'num_votes': 230175,
#   'attributes': 'Excitement, Suspense, Inspiration, Humor, Tension, Empathy, Surprise, Intrigue'},
#  'When Harry Met Sally...': {'movie_id': 98635,
#   'year': 1989,
#   'genres': 'Comedy,Drama,Romance',
#   'average_rating': 7.7,
#   'num_votes': 230153,
#   'attributes': 'Romantic, Funny, Heartwarming, Charming, Witty, Nostalgic, Relatable, Entertaining'},
#  'Shakespeare in Love': {'movie_id': 138097,
#   'year': 1998,
#   'genres': 'Comedy,Drama,History',
#   'average_rating': 7.1,
#   'num_votes': 230078,
#   'attributes': 'Romantic, Inspirational, Humorous, Passionate, Charming, Nostalgic, Witty, Heartwarming'},
#  'Safe House': {'movie_id': 1599348,
#   'year': 2012,
#   'genres': 'Action,Thriller',
#   'average_rating': 6.7,
#   'num_votes': 229764,
#   'attributes': 'Excitement, Suspense, Tension, Adrenaline, Intrigue, Fear, Intensity, Nervousness'},
#  'Ip Man': {'movie_id': 1220719,
#   'year': 2008,
#   'genres': 'Action,Biography,Drama',
#   'average_rating': 8.0,
#   'num_votes': 229523,
#   'attributes': 'Excitement, Suspense, Inspiration, Determination, Resilience, Hope, Courage, Unity'},
#  'Napoleon Dynamite': {'movie_id': 374900,
#   'year': 2004,
#   'genres': 'Comedy',
#   'average_rating': 7.0,
#   'num_votes': 229261,
#   'attributes': 'quirky, awkward, nostalgic, lighthearted, offbeat, deadpan, eccentric, whimsical'},
#  'Closer': {'movie_id': 376541,
#   'year': 2004,
#   'genres': 'Drama,Romance',
#   'average_rating': 7.2,
#   'num_votes': 228794,
#   'attributes': 'Intense, Passionate, Intriguing, Complicated, Deceptive, Emotional, Tense, Suspenseful'},
#  'Sunset Blvd.': {'movie_id': 43014,
#   'year': 1950,
#   'genres': 'Drama,Film-Noir',
#   'average_rating': 8.4,
#   'num_votes': 228786,
#   'attributes': 'excitement, suspense, intrigue, nostalgia, fascination, tension, melancholy, curiosity'},
#  'Clerks': {'movie_id': 109445,
#   'year': 1994,
#   'genres': 'Comedy',
#   'average_rating': 7.7,
#   'num_votes': 228121,
#   'attributes': 'humorous, lighthearted, entertaining, witty, amusing, comical, funny, enjoyable'},
#  'Cowboys & Aliens': {'movie_id': 409847,
#   'year': 2011,
#   'genres': 'Action,Drama,Sci-Fi',
#   'average_rating': 6.0,
#   'num_votes': 227268,
#   'attributes': 'Excitement, Suspense, Adventure, Thrill, Tension, Surprise, Amazement, Anticipation'},
#  'Ghost': {'movie_id': 99653,
#   'year': 1990,
#   'genres': 'Drama,Fantasy,Romance',
#   'average_rating': 7.1,
#   'num_votes': 227207,
#   'attributes': 'Romantic, Suspenseful, Heartwarming, Mysterious, Touching, Thrilling, Sentimental, Intense'},
#  "Bram Stoker's Dracula": {'movie_id': 103874,
#   'year': 1992,
#   'genres': 'Drama,Fantasy,Horror',
#   'average_rating': 7.4,
#   'num_votes': 227166,
#   'attributes': 'Excitement, Suspense, Fear, Intrigue, Romance, Mystery, Thrill, Tension'},
#  'The Bridge on the River Kwai': {'movie_id': 50212,
#   'year': 1957,
#   'genres': 'Adventure,Drama,War',
#   'average_rating': 8.1,
#   'num_votes': 227095,
#   'attributes': 'Excitement, Suspense, Tension, Courage, Determination, Sacrifice, Loyalty, Triumph'},
#  'Captain Fantastic': {'movie_id': 3553976,
#   'year': 2016,
#   'genres': 'Comedy,Drama',
#   'average_rating': 7.8,
#   'num_votes': 227091,
#   'attributes': 'joy, curiosity, introspection, love, adventure, empathy, inspiration, hope'},
#  'Blade II': {'movie_id': 187738,
#   'year': 2002,
#   'genres': 'Action,Horror,Sci-Fi',
#   'average_rating': 6.7,
#   'num_votes': 227048,
#   'attributes': 'Excitement, Suspense, Fear, Thrill, Tension, Intensity, Adrenaline, Intrigue'},
#  'The Ides of March': {'movie_id': 1124035,
#   'year': 2011,
#   'genres': 'Drama,Thriller',
#   'average_rating': 7.1,
#   'num_votes': 226925,
#   'attributes': 'excitement, suspense, intrigue, tension, betrayal, ambition, disillusionment, manipulation'},
#  'Big Daddy': {'movie_id': 142342,
#   'year': 1999,
#   'genres': 'Comedy,Drama',
#   'average_rating': 6.4,
#   'num_votes': 226778,
#   'attributes': 'Excitement, humor, warmth, joy, surprise, nostalgia, empathy, satisfaction'},
#  'Ace Ventura: When Nature Calls': {'movie_id': 112281,
#   'year': 1995,
#   'genres': 'Adventure,Comedy,Crime',
#   'average_rating': 6.4,
#   'num_votes': 226471,
#   'attributes': 'Excitement, Laughter, Intrigue, Adventure, Amusement, Curiosity, Entertainment, Fun'},
#  'Rocky Balboa': {'movie_id': 479143,
#   'year': 2006,
#   'genres': 'Action,Drama,Sport',
#   'average_rating': 7.1,
#   'num_votes': 226133,
#   'attributes': 'Excitement, Inspiration, Determination, Adrenaline, Triumph, Courage, Grit, Intensity'},
#  'Fast & Furious Presents: Hobbs & Shaw': {'movie_id': 6806448,
#   'year': 2019,
#   'genres': 'Action,Adventure,Thriller',
#   'average_rating': 6.5,
#   'num_votes': 225870,
#   'attributes': 'Excitement, Suspense, Thrill, Action, Adventure, Intensity, Adrenaline, Tension'},
#  'Thank You for Smoking': {'movie_id': 427944,
#   'year': 2005,
#   'genres': 'Comedy,Drama',
#   'average_rating': 7.5,
#   'num_votes': 225796,
#   'attributes': 'Humor, satire, irony, wit, sarcasm, amusement, laughter, entertainment'},
#  "Carlito's Way": {'movie_id': 106519,
#   'year': 1993,
#   'genres': 'Crime,Drama,Thriller',
#   'average_rating': 7.9,
#   'num_votes': 225776,
#   'attributes': 'Excitement, Suspense, Tension, Intrigue, Drama, Thrill, Intensity, Anticipation'},
#  'Everest': {'movie_id': 2719848,
#   'year': 2015,
#   'genres': 'Action,Adventure,Biography',
#   'average_rating': 7.1,
#   'num_votes': 225415,
#   'attributes': 'Excitement, Thrill, Adventure, Inspiration, Determination, Courage, Suspense, Triumph'},
#  'The Ugly Truth': {'movie_id': 1142988,
#   'year': 2009,
#   'genres': 'Comedy,Romance',
#   'average_rating': 6.4,
#   'num_votes': 225287,
#   'attributes': 'Excitement, Romance, Humor, Joy, Entertainment, Fun, Amusement, Delight'},
#  "Rosemary's Baby": {'movie_id': 63522,
#   'year': 1968,
#   'genres': 'Drama,Horror',
#   'average_rating': 8.0,
#   'num_votes': 225154,
#   'attributes': 'Suspense, Fear, Intrigue, Tension, Unease, Dread, Apprehension, Curiosity'},
#  'A Fistful of Dollars': {'movie_id': 58461,
#   'year': 1964,
#   'genres': 'Action,Drama,Western',
#   'average_rating': 7.9,
#   'num_votes': 225007,
#   'attributes': 'Excitement, Suspense, Thrill, Intensity, Tension, Intrigue, Anticipation, Drama'},
#  'King Arthur: Legend of the Sword': {'movie_id': 1972591,
#   'year': 2017,
#   'genres': 'Action,Adventure,Drama',
#   'average_rating': 6.7,
#   'num_votes': 224969,
#   'attributes': 'excitement, adventure, determination, struggle, discovery, transformation, loyalty, destiny'},
#  'Daredevil': {'movie_id': 287978,
#   'year': 2003,
#   'genres': 'Action,Crime',
#   'average_rating': 5.3,
#   'num_votes': 224950,
#   'attributes': 'Excitement, Suspense, Thrilling, Intense, Action-packed, Adrenaline-fueled, Engaging, Captivating'},
#  'Die Another Day': {'movie_id': 246460,
#   'year': 2002,
#   'genres': 'Action,Adventure,Thriller',
#   'average_rating': 6.1,
#   'num_votes': 224401,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Action, Intrigue, Tension, Mystery'},
#  'The Croods': {'movie_id': 481499,
#   'year': 2013,
#   'genres': 'Action,Adventure,Animation',
#   'average_rating': 7.2,
#   'num_votes': 224382,
#   'attributes': 'Excitement, Adventure, Wonder, Amazement, Joy, Thrill, Curiosity, Fascination'},
#  'Planet of the Apes': {'movie_id': 133152,
#   'year': 2001,
#   'genres': 'Action,Adventure,Sci-Fi',
#   'average_rating': 5.7,
#   'num_votes': 224341,
#   'attributes': 'Excitement, Suspense, Thrill, Adventure, Wonder, Amazement, Curiosity, Intrigue'},
#  'The Polar Express': {'movie_id': 338348,
#   'year': 2004,
#   'genres': 'Adventure,Animation,Comedy',
#   'average_rating': 6.6,
#   'num_votes': 224189,
#   'attributes': 'excitement, wonder, joy, nostalgia, warmth, anticipation, awe, enchantment'},
#  'Chef': {'movie_id': 2883512,
#   'year': 2014,
#   'genres': 'Adventure,Comedy,Drama',
#   'average_rating': 7.3,
#   'num_votes': 224128,
#   'attributes': 'Excitement, Joy, Inspiration, Satisfaction, Warmth, Nostalgia, Hope, Contentment'},
#  'The Evil Dead': {'movie_id': 83907,
#   'year': 1981,
#   'genres': 'Horror',
#   'average_rating': 7.4,
#   'num_votes': 224121,
#   'attributes': 'Excitement, Suspense, Fear, Thrill, Tension, Dread, Shock, Surprise'},
#  'Remember the Titans': {'movie_id': 210945,
#   'year': 2000,
#   'genres': 'Biography,Drama,Sport',
#   'average_rating': 7.8,
#   'num_votes': 224026,
#   'attributes': 'Excitement, Inspiration, Empowerment, Unity, Determination, Overcoming adversity, Teamwork, Triumph'},
#  'Pain & Gain': {'movie_id': 1980209,
#   'year': 2013,
#   'genres': 'Action,Comedy,Crime',
#   'average_rating': 6.4,
#   'num_votes': 223983,
#   'attributes': 'Excitement, Humor, Suspense, Thrill, Surprise, Intrigue, Amusement, Tension'},
#  'Get Smart': {'movie_id': 425061,
#   'year': 2008,
#   'genres': 'Action,Adventure,Comedy',
#   'average_rating': 6.5,
#   'num_votes': 223848,
#   'attributes': 'Excitement, humor, suspense, adventure, thrill, amusement, entertainment, joy'},
#  'Dogma': {'movie_id': 120655,
#   'year': 1999,
#   'genres': 'Adventure,Comedy,Drama',
#   'average_rating': 7.3,
#   'num_votes': 223703,
#   'attributes': 'Excitement, Humor, Suspense, Surprise, Joy, Amusement, Intrigue, Satisfaction'},
#  'Little Women': {'movie_id': 3281548,
#   'year': 2019,
#   'genres': 'Drama,Romance',
#   'average_rating': 7.8,
#   'num_votes': 223394,
#   'attributes': 'nostalgic, heartwarming, empowering, inspiring, bittersweet, uplifting, thought-provoking, romantic'},
#  'Match Point': {'movie_id': 416320,
#   'year': 2005,
#   'genres': 'Drama,Romance,Thriller',
#   'average_rating': 7.6,
#   'num_votes': 223254,
#   'attributes': 'Excitement, Suspense, Intrigue, Love, Passion, Tension, Desire, Betrayal'},
#  'Rocky II': {'movie_id': 79817,
#   'year': 1979,
#   'genres': 'Drama,Sport',
#   'average_rating': 7.3,
#   'num_votes': 223151,
#   'attributes': 'determined, motivated, resilient, passionate, determined, intense, emotional, triumphant'},
#  'Misery': {'movie_id': 100157,
#   'year': 1990,
#   'genres': 'Drama,Thriller',
#   'average_rating': 7.8,
#   'num_votes': 223054,
#   'attributes': 'Suspense, fear, tension, anxiety, dread, unease, paranoia, terror'},
#  'Godzilla vs. Kong': {'movie_id': 5034838,
#   'year': 2021,
#   'genres': 'Action,Sci-Fi,Thriller',
#   'average_rating': 6.3,
#   'num_votes': 222703,
#   'attributes': 'Excitement, Suspense, Fear, Wonder, Thrill, Intensity, Adrenaline, Tension'},
#  'Anger Management': {'movie_id': 305224,
#   'year': 2003,
#   'genres': 'Comedy',
#   'average_rating': 6.2,
#   'num_votes': 222485,
#   'attributes': 'Excitement, Laughter, Surprise, Tension, Happiness, Amusement, Relaxation, Intrigue'},
#  'Project X': {'movie_id': 1636826,
#   'year': 2012,
#   'genres': 'Comedy',
#   'average_rating': 6.6,
#   'num_votes': 222302,
#   'attributes': 'excitement, chaos, thrill, frenzy, exhilaration, mischief, mayhem, frenzy'}}

# %%
with open("../data/processed/final_data.json", "w") as f:
    json.dump(json_data, f)
